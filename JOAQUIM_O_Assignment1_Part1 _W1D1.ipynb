# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %%
climate_data = pd.read_csv('A1_Barajas_station_data.csv'
                         , skiprows=1
                        , names = ['Year','Month','Day','Average Temperature','Maximum temperature','Minimum temperature','Average atmospheric pressure at sea level',
                                'Average atmospheric pressure at the station level',
                                'Average relative humidity',
                                'Total rainfall and / or snowmelt',
                                'Average visibility',
                                'Average wind speed',
                                'Maximum sustained wind speed',
                                'Maximum speed of wind',
                                'Indicator for occurrence of: Fog',
                                'Indicator for occurrence of: Rain or Drizzle',
                                'Indicator for occurrence of: Snow or Ice Pellets',
                                'Indicator for occurrence of: Hail',
                                'Indicator for occurrence of: Thunder',
                                'Indicator for occurrence of: Tornado / Funnel cloud'],
                        parse_dates={'date' : ['Day','Month', 'Year']} 
                       )
climate_data.head(5)
# Out:
#         date  Average Temperature  Maximum temperature  Minimum temperature  \
# 0 1991-01-01                 5.30                 9.60                 0.00
# 1 1991-02-01                 2.60                 6.40                 0.00
# 2 1991-03-01                 2.30                 5.20                -1.00
# 3 1991-04-01                 3.90                10.00                 0.00
# 4 1991-05-01                 2.90                10.40                -3.00
#
#   Average atmospheric pressure at sea level  \
# 0                                         -
# 1                                         -
# 2                                         -
# 3                                         -
# 4                                         -
#
#   Average atmospheric pressure at the station level Average relative humidity  \
# 0                                                 -                        86
# 1                                                 -                        88
# ...

# %%
climate_data .dtypes
# Out:
# date                                                   datetime64[ns]
# Average Temperature                                           float64
# Maximum temperature                                           float64
# Minimum temperature                                           float64
# Average atmospheric pressure at sea level                      object
# Average atmospheric pressure at the station level              object
# Average relative humidity                                      object
# Total rainfall and / or snowmelt                               object
# Average visibility                                            float64
# Average wind speed                                            float64
# Maximum sustained wind speed                                   object
# Maximum speed of wind                                          object
# Indicator for occurrence of: Fog                                int64
# ...

# %%
# landtemps.rename(columns={'stationElevation' : 'stnElv'}, inplace=True)

# %%
# landtemps.sample(5)

# %%
climate_data.shape
# Out:
# (1826, 18)

# %%
climate_data.isnull().sum()
# Out:
# date                                                    0
# Average Temperature                                    10
# Maximum temperature                                     0
# Minimum temperature                                     2
# Average atmospheric pressure at sea level               0
# Average atmospheric pressure at the station level       0
# Average relative humidity                               5
# Total rainfall and / or snowmelt                        0
# Average visibility                                      0
# Average wind speed                                      0
# Maximum sustained wind speed                            0
# Maximum speed of wind                                   0
# Indicator for occurrence of: Fog                        0
# Indicator for occurrence of: Rain or Drizzle            0
# Indicator for occurrence of: Snow or Ice Pellets        0
# Indicator for occurrence of: Hail                       0
# ...

# %%
climate_data.dropna(subset=['Average Temperature'], inplace=True)

# %%
climate_data.dropna(subset=['Minimum temperature'], inplace=True)

# %%
climate_data.dropna(subset=['Average relative humidity'], inplace=True)

# %%
climate_data.dropna(inplace=True)

# %%
climate_data.shape
# Out:
# (1810, 18)

# %%
climate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1810 entries, 0 to 1825
# Data columns (total 18 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   date                                                 1810 non-null   datetime64[ns]
#  1   Average Temperature                                  1810 non-null   float64
#  2   Maximum temperature                                  1810 non-null   float64
#  3   Minimum temperature                                  1810 non-null   float64
#  4   Average atmospheric pressure at sea level            1810 non-null   object
#  5   Average atmospheric pressure at the station level    1810 non-null   object
#  6   Average relative humidity                            1810 non-null   object
#  7   Total rainfall and / or snowmelt                     1810 non-null   object
# ...

# %%
climate_data= climate_data.apply( pd.to_numeric, errors='coerce' )

# %%
climate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1810 entries, 0 to 1825
# Data columns (total 18 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   date                                                 1810 non-null   int64
#  1   Average Temperature                                  1810 non-null   float64
#  2   Maximum temperature                                  1810 non-null   float64
#  3   Minimum temperature                                  1810 non-null   float64
#  4   Average atmospheric pressure at sea level            890 non-null    float64
#  5   Average atmospheric pressure at the station level    1538 non-null   float64
#  6   Average relative humidity                            1806 non-null   float64
#  7   Total rainfall and / or snowmelt                     1809 non-null   float64
# ...

# %%
# Out:
#                     date  Average Temperature  Maximum temperature  \
# 0     662688000000000000                 5.30                 9.60
# 1     665366400000000000                 2.60                 6.40
# 2     667785600000000000                 2.30                 5.20
# 3     670464000000000000                 3.90                10.00
# 4     673056000000000000                 2.90                10.40
# ...                  ...                  ...                  ...
# 1821  820022400000000000                 9.70                11.00
# 1822  820108800000000000                11.30                14.00
# 1823  820195200000000000                 9.00                10.20
# 1824  820281600000000000                11.50                14.00
# 1825  820368000000000000                11.30                14.00
#
#       Minimum temperature  Average atmospheric pressure at sea level  \
# 0                    0.00                                        NaN
# ...

# %%
pd.to_datetime(climate_data['date']).apply(lambda x: x.date())
# Out:
# 0       1991-01-01
# 1       1991-02-01
# 2       1991-03-01
# 3       1991-04-01
# 4       1991-05-01
#            ...
# 1821    1995-12-27
# 1822    1995-12-28
# 1823    1995-12-29
# 1824    1995-12-30
# 1825    1995-12-31
# Name: date, Length: 1810, dtype: object

# %%
climate_data.describe().T
# Out:
#                                                       count  \
# date                                               1,810.00
# Average Temperature                                1,810.00
# Maximum temperature                                1,810.00
# Minimum temperature                                1,810.00
# Average atmospheric pressure at sea level            890.00
# Average atmospheric pressure at the station level  1,538.00
# Average relative humidity                          1,806.00
# Total rainfall and / or snowmelt                   1,809.00
# Average visibility                                 1,810.00
# Average wind speed                                 1,810.00
# Maximum sustained wind speed                       1,806.00
# Maximum speed of wind                                321.00
# Indicator for occurrence of: Fog                   1,810.00
# Indicator for occurrence of: Rain or Drizzle       1,810.00
# Indicator for occurrence of: Snow or Ice Pellets   1,810.00
# ...
